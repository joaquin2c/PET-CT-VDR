# %%
ls ../../shared_data/Mediastinal-Lymph-Node-SEG/Mediastinal-Lymph-Node-SEG-DA-RAD/Mediastinal-Lymph-Node-SEG/case_0005/"11-08-2011-42903/3.000000-25718"
# Out:
# 1-001.dcm  1-016.dcm  1-031.dcm  1-046.dcm  1-061.dcm  1-076.dcm  1-091.dcm
# 1-002.dcm  1-017.dcm  1-032.dcm  1-047.dcm  1-062.dcm  1-077.dcm  1-092.dcm
# 1-003.dcm  1-018.dcm  1-033.dcm  1-048.dcm  1-063.dcm  1-078.dcm  1-093.dcm
# 1-004.dcm  1-019.dcm  1-034.dcm  1-049.dcm  1-064.dcm  1-079.dcm  1-094.dcm
# 1-005.dcm  1-020.dcm  1-035.dcm  1-050.dcm  1-065.dcm  1-080.dcm  1-095.dcm
# 1-006.dcm  1-021.dcm  1-036.dcm  1-051.dcm  1-066.dcm  1-081.dcm  1-096.dcm
# 1-007.dcm  1-022.dcm  1-037.dcm  1-052.dcm  1-067.dcm  1-082.dcm  1-097.dcm
# 1-008.dcm  1-023.dcm  1-038.dcm  1-053.dcm  1-068.dcm  1-083.dcm  1-098.dcm
# 1-009.dcm  1-024.dcm  1-039.dcm  1-054.dcm  1-069.dcm  1-084.dcm  1-099.dcm
# 1-010.dcm  1-025.dcm  1-040.dcm  1-055.dcm  1-070.dcm  1-085.dcm  1-100.dcm
# 1-011.dcm  1-026.dcm  1-041.dcm  1-056.dcm  1-071.dcm  1-086.dcm  1-101.dcm
# 1-012.dcm  1-027.dcm  1-042.dcm  1-057.dcm  1-072.dcm  1-087.dcm
# 1-013.dcm  1-028.dcm  1-043.dcm  1-058.dcm  1-073.dcm  1-088.dcm
# ...

# %%
dcm_path="../../shared_data/Mediastinal-Lymph-Node-SEG/Mediastinal-Lymph-Node-SEG-DA-RAD/Mediastinal-Lymph-Node-SEG/case_0005/11-08-2011-42903/3.000000-25718"

# %%
import pydicom as dicom
ds = dicom.dcmread(dcm_path).pixel_array
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pydicom as dicom
# ----> 2 ds = dicom.dcmread(dcm_path).pixel_array
#
# File ~/.conda_envs/ctencoders/lib/python3.10/site-packages/pydicom/filereader.py:1042, in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#    1040     caller_owns_file = False
#    1041     logger.debug(f"Reading file '{fp}'")
# -> 1042     fp = open(fp, "rb")
#    1043 elif (
#    1044     fp is None
#    1045     or not hasattr(fp, "read")
#    1046     or not hasattr(fp, "seek")
#    1047     or not hasattr(fp, "tell")
#    1048 ):
#    1049     raise TypeError(
#    1050         "dcmread: Expected a file path, file-like or readable buffer, "
#    1051         f"but got {type(fp).__name__}"
#    1052     )
#
# ...

# %%
import pandas as pd
import os
path="../../shared_data/Mediastinal-Lymph-Node-SEG"
df=pd.read_csv(os.path.join(path,"Mediastinal-Lymph-Node-SEG-DA-RAD/metadata.csv"))
df.head()
# Out:
#                                           Series UID  \
# 0  1.3.6.1.4.1.14519.5.2.1.2428329690538376039199...
# 1  1.3.6.1.4.1.14519.5.2.1.2576934312320596685159...
# 2  1.3.6.1.4.1.14519.5.2.1.1085281521159144847527...
# 3  1.3.6.1.4.1.14519.5.2.1.7690235095448347848036...
# 4  1.3.6.1.4.1.14519.5.2.1.7452242842764931610698...
#
#                    Collection 3rd Party Analysis  \
# 0  Mediastinal-Lymph-Node-SEG                 NO
# 1  Mediastinal-Lymph-Node-SEG                 NO
# 2  Mediastinal-Lymph-Node-SEG                 NO
# 3  Mediastinal-Lymph-Node-SEG                 NO
# 4  Mediastinal-Lymph-Node-SEG                 NO
#
#                 Data Description URI Subject ID  \
# 0  https://doi.org/10.7937/QVAZ-JA09  case_0441
# 1  https://doi.org/10.7937/QVAZ-JA09  case_0761
# 2  https://doi.org/10.7937/QVAZ-JA09  case_0775
# 3  https://doi.org/10.7937/QVAZ-JA09  case_0906
# 4  https://doi.org/10.7937/QVAZ-JA09  case_0164
#
# ...

# %%
 df["File Location"][0]
# Out:
# './Mediastinal-Lymph-Node-SEG/case_0441/09-07-2011-29183/1000.000000-Partially Annotated-36645'

# %%
aa=[1,2,243,25,2623,27,25,627,468,568]
aa.sort()
aa
# Out:
# [1, 2, 25, 25, 27, 243, 468, 568, 627, 2623]

# %%
import numpy as np
def get_dcm(path):
    pat_files=os.listdir(path)
    pat_files.sort()
    img_3d=[]
    for i in pat_files:
        img_3d.append(dicom.dcmread(os.path.join(path,i)).pixel_array)
    array_3d = np.array(img_3d)
    D, H, W = np.shape(array_3d)
    return array_3d.reshape(H,W,D)

# %%
ls '../../shared_data/Mediastinal-Lymph-Node-SEG/Mediastinal-Lymph-Node-SEG-DA-RAD/Mediastinal-Lymph-Node-SEG/case_0270/10-03-2017-48102/9.000000-19707'
# Out:
# 1-001.dcm  1-019.dcm  1-037.dcm  1-055.dcm  1-073.dcm  1-091.dcm  1-109.dcm
# 1-002.dcm  1-020.dcm  1-038.dcm  1-056.dcm  1-074.dcm  1-092.dcm  1-110.dcm
# 1-003.dcm  1-021.dcm  1-039.dcm  1-057.dcm  1-075.dcm  1-093.dcm  1-111.dcm
# 1-004.dcm  1-022.dcm  1-040.dcm  1-058.dcm  1-076.dcm  1-094.dcm  1-112.dcm
# 1-005.dcm  1-023.dcm  1-041.dcm  1-059.dcm  1-077.dcm  1-095.dcm  1-113.dcm
# 1-006.dcm  1-024.dcm  1-042.dcm  1-060.dcm  1-078.dcm  1-096.dcm  1-114.dcm
# 1-007.dcm  1-025.dcm  1-043.dcm  1-061.dcm  1-079.dcm  1-097.dcm  1-115.dcm
# 1-008.dcm  1-026.dcm  1-044.dcm  1-062.dcm  1-080.dcm  1-098.dcm  1-116.dcm
# 1-009.dcm  1-027.dcm  1-045.dcm  1-063.dcm  1-081.dcm  1-099.dcm  1-117.dcm
# 1-010.dcm  1-028.dcm  1-046.dcm  1-064.dcm  1-082.dcm  1-100.dcm  1-118.dcm
# 1-011.dcm  1-029.dcm  1-047.dcm  1-065.dcm  1-083.dcm  1-101.dcm  1-119.dcm
# 1-012.dcm  1-030.dcm  1-048.dcm  1-066.dcm  1-084.dcm  1-102.dcm  1-120.dcm
# ...

# %%
path_pat="../../shared_data/Mediastinal-Lymph-Node-SEG/Mediastinal-Lymph-Node-SEG-DA-RAD/Mediastinal-Lymph-Node-SEG/"
datas={"case":[],"path":[],"ct_segmentation":[]}
for i in os.listdir(path_pat):
    folder_paths=os.path.join(path_pat,i)
    if os.path.isdir(folder_paths):
        ff=os.listdir(folder_paths)[0]
        folder_path=os.path.join(folder_paths,ff)
        files_path=os.listdir(folder_path)
        for j in files_path:
            if not "Annotated" in j:
                pp=j
                pat_folder=os.path.join(folder_path,pp)
                #pat_files=get_dcm(pat_folder)
                #print(np.shape(pat_files))
                datas["case"].append(i)
                datas["path"].append(os.path.join(ff,pp))
                datas["ct_segmentation"].append(True)

# %%
xddd=pd.DataFrame(datas)
xddd
# Out:
#           case                               path  ct_segmentation
# 0    case_0270    10-03-2017-48102/9.000000-19707             True
# 1    case_0303    12-06-2004-36126/2.000000-90406             True
# 2    case_0695    06-05-2011-05331/2.000000-43718             True
# 3    case_0742    12-05-2013-21366/5.000000-19298             True
# 4    case_0030    06-29-2012-17045/2.000000-44751             True
# ..         ...                                ...              ...
# 508  case_0400  04-23-2019-13778/302.000000-06413             True
# 509  case_0032    01-11-2012-62340/2.000000-67295             True
# 510  case_0955   01-11-2010-38766/19.000000-89579             True
# 511  case_0596    06-26-2016-34524/6.000000-06510             True
# 512  case_0132    07-02-2010-08414/2.000000-16183             True
#
# [513 rows x 3 columns]

# %%
xddd.to_csv('MLNS.csv',index=False)

# %%
pd.DataFrame

# %%
ay=xddd.iloc[0]
pat_files=get_dcm(os.path.join(path_pat,ay["case"],ay["path"]))
np.shape(pat_files)
# Out:
# D : 122, H : 512, W : 512
# (512, 512, 122)

# %%
ls ../../shared_data/Mediastinal-Lymph-Node-SEG/Mediastinal-Lymph-Node-SEG-DA-RAD/Mediastinal-Lymph-Node-SEG/case_0270
# Out:
# 10-03-2017-48102/

# %%
import matplotlib.pyplot as plt
plt.imshow(ds[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.imshow(ds[2])
#
# File ~/.conda_envs/ctencoders/lib/python3.10/site-packages/matplotlib/pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(ds)

# %%
ds
# Out:
# array([[-2048, -2048, -2048, ..., -2048, -2048, -2048],
#        [-2048, -2048, -2048, ..., -2048, -2048, -2048],
#        [-2048, -2048, -2048, ..., -2048, -2048, -2048],
#        ...,
#        [-2048, -2048, -2048, ..., -2048, -2048, -2048],
#        [-2048, -2048, -2048, ..., -2048, -2048, -2048],
#        [-2048, -2048, -2048, ..., -2048, -2048, -2048]], dtype=int16)

# %%
dcm_path="../../shared_data/Mediastinal-Lymph-Node-SEG/Mediastinal-Lymph-Node-SEG-DA-RAD/Mediastinal-Lymph-Node-SEG/case_0005/11-08-2011-42903/3.000000-25718"

# %%
image_test=get_dcm(dcm_path)

# %%
plt.imshow(image_test[0])

# %%
plt.imshow(image_test[4])

# %%
for i in image_test:
    print(np.shape(i))
# Out:
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# (512, 512)
# ...

# %%
import imageio
with imageio.get_writer('3d.gif', mode='I', duration=0.1) as writer: # duration in seconds
    for image in image_test_after:
        writer.append_data(image)

# %%
pip install imageio
# Out:
# ...
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# ...
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def windowing_ct(width, level):
    lower_bound = level - width/2
    upper_bound = level + width/2
    return lower_bound, upper_bound

def apply_window_ct(ct, width, level):
    """ Normalize CT image using a window in the HU scale

    Args:
        ct (np.array): ct image.
        width (int): window width in the HU scale.
        level (int): center of the windows in the HU scale.

    Returns:
        ct (np.array): Normalized image in a range 0-1.

    """
    ct_min_val, ct_max_val = windowing_ct(width, level)
    ct_range = ct_max_val - ct_min_val
    ct = (ct - ct_min_val) / ct_range
    ct = np.clip(ct, 0, 1)
    return ct

# %%
image_test_after=apply_window_ct(image_test, width=1800, level=40)*255

# %%
import matplotlib.pyplot as plt
plt.imshow(image_test_after[-1])
